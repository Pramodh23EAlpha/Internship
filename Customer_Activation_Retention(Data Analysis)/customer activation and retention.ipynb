# %% [markdown]
# # Problem : Data Analysis on Factors for Customer Activation and Retention

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel (r'D:\DataTrained\Customer_retention_dataset\customer_retention_dataset_extracted.xlsx')

dfr = pd.DataFrame(df)


dfr.columns = dfr.columns.str.replace(' ', '')

df.columns = df.columns.str.replace('\t','')

print(dfr.columns)
# Out:
# Index(['1Genderofrespondent', '2Howoldareyou?',
#        '3Whichcitydoyoushoponlinefrom?',
#        '4WhatisthePinCodeofwhereyoushoponlinefrom?',
#        '5SinceHowLongYouareShoppingOnline?',
#        '6Howmanytimesyouhavemadeanonlinepurchaseinthepast1year?',
#        '7Howdoyouaccesstheinternetwhileshoppingon-line?',
#        '8Whichdevicedoyouusetoaccesstheonlineshopping?',
#        '9Whatisthescreensizeofyourmobiledevice?',
#        '10Whatistheoperatingsystem(OS)ofyourdevice?',
#        '11Whatbrowserdoyourunonyourdevicetoaccessthewebsite?',
#        '12Whichchanneldidyoufollowtoarriveatyourfavoriteonlinestoreforthefirsttime?',
#        '13Afterfirstvisit,howdoyoureachtheonlineretailstore?',
#        '14Howmuchtimedoyouexplorethee-retailstorebeforemakingapurchasedecision?',
#        '15WhatisyourpreferredpaymentOption?',
#        '16Howfrequentlydoyouabandon(selectinganitemsandleavingwithoutmakingpayment)yourshoppingcart?',
#        '17Whydidyouabandonthe“Bag”,“ShoppingCart”?',
# ...

# %%
dfr.isnull().sum()

# %%
print(dfr.head(10))

# %%
dfr.groupby('1Genderofrespondent').size().plot(kind='pie', autopct='%.2f', title ='Gender visualization')
# Out:
# <AxesSubplot:title={'center':'Gender visualization'}, ylabel='None'>

# %%
dfr.groupby('2Howoldareyou?').size().plot(kind='bar' , title = 'Age visualization')
# Out:
# <AxesSubplot:title={'center':'Age visualization'}, xlabel='2Howoldareyou?'>

# %%
dfr.groupby('3Whichcitydoyoushoponlinefrom?').size().plot(kind='bar',title = 'City shopped most')

# %%
dfr.groupby('8Whichdevicedoyouusetoaccesstheonlineshopping?').size().plot(kind='bar',title = 'Device Used')

# %%
dfr.groupby('12Whichchanneldidyoufollowtoarriveatyourfavoriteonlinestoreforthefirsttime?').size().plot(kind='bar',title = 'Device Used')

# %% [markdown]
#  As per the case study :  customer loyality is based on the combination of both utilitarian value and hedonistic values
#  we will split the data into these two and see how much it affects customer loyality

# %% [markdown]
# definition:
#
#
# Utilitarian value is defined as that value that a customer receives based on a task-related
# and rational consumption behavior
#
#
# The hedonic values are related to gratification of the senses
# enhanced through experiences of pleasure, entertainment, fantasy and playfulness

# %% [markdown]
# ### Now We will categorize the data into Utilitarian Value , Hedonic Value , Platform experience

# %%
utilitarian_values = ['47Gettingvalueformoneyspent','46Shoppingonthewebsitehelpsyoufulfillcertainroles','41Monetarysavings',
                     '40Provisionofcompleteandrelevantproductinformation','39Offeringawidevarietyoflistedproductinseveralcategory','35DisplayingqualityInformationonthewebsiteimprovessatisfactionofcustomers','32Shoppingonlineisconvenientandflexible','30Onlineshoppinggivesmonetarybenefitanddiscounts']


hedonic_values = ['45Youfeelgratificationshoppingonyourfavoritee-tailer','44Shoppingonyourpreferrede-tailerenhancesyoursocialstatus','43Shoppingonthewebsitegivesyouthesenseofadventure','31Enjoymentisderivedfromshoppingonline']


platform_experience_values=['22Easeofnavigationinwebsite','23Loadingandprocessingspeed','24UserfriendlyInterfaceofthewebsite','25ConvenientPaymentmethods','29Responsiveness,availabilityofseveralcommunicationchannels(email,onlinerep,twitter,phoneetc.)']

# %% [markdown]
# ### Visualizing how the platform(Application interfcae) has effect on  the customer retention / Activation

# %%
for i in platform_experience_values:
        plt.figure(figsize=(5,4))
        dfr[i].value_counts().plot.pie(autopct='%1.1f%%')
        centre=plt.Circle((0,0),0.7,fc='white')
        fig=plt.gcf()
        fig.gca().add_artist(centre)
        plt.xlabel(i)
        plt.ylabel('')
        plt.figure()

# %% [markdown]
# We can see Application interface / UI/UX  plays a major factor as many user prefer and agree for convinient and userfriendly
# interface

# %% [markdown]
# ###  Lets see how   set of Hedonic values effect  customer activation and retention

# %%
for i in hedonic_values:
        plt.figure(figsize=(5,4))
        dfr[i].value_counts().plot.pie(autopct='%1.1f%%')
        centre=plt.Circle((0,0),0.7,fc='white')
        fig=plt.gcf()
        fig.gca().add_artist(centre)
        plt.xlabel(i)
        plt.ylabel('')
        plt.figure()

# %% [markdown]
# ### Lets see how  Utilitarian values effect customer activation and retention

# %%
for i in utilitarian_values:
        plt.figure(figsize=(5,4))
        dfr[i].value_counts().plot.pie(subplots=True, autopct='%1.1f%%')
        centre=plt.Circle((0,0),0.7,fc='white')
        fig=plt.gcf()
        fig.gca().add_artist(centre)
        plt.xlabel(i)
        plt.ylabel('')
        ax.grid(False)
        plt.figure()

# %% [markdown]
# ## Customer satisfaction (Label in our analysis)

# %%
dfr.groupby('WhichoftheIndianonlineretailerwouldyourecommendtoafriend?').size().plot(kind='bar' , title = 'Most recommended ')
# Out:
# <AxesSubplot:title={'center':'Most recommended '}, xlabel='WhichoftheIndianonlineretailerwouldyourecommendtoafriend?'>

# %% [markdown]
# ## Brand rating / Review collected against label

# %%
customer_review=['Easytousewebsiteorapplication',
       'Visualappealingweb-pagelayout', 'Wildvarietyofproductonoffer',
       'Complete,relevantdescriptioninformationofproducts',
       'Fastloadingwebsitespeedofwebsiteandapplication',
       'Reliabilityofthewebsiteorapplication',
       'Quicknesstocompletepurchase',
       'Availabilityofseveralpaymentoptions', 'Speedyorderdelivery',
       'Privacyofcustomers’information',
       'Securityofcustomerfinancialinformation',
       'PerceivedTrustworthiness',
       'Presenceofonlineassistancethroughmulti-channel']

# %% [markdown]
# ####  We will compare all the customer review with the highest recommended  E Platform brand

# %%
warnings.filterwarnings("ignore")
for i in customer_review:
        plt.figure(figsize=(20,6))
        sns.countplot(dfr[i],hue=dfr['WhichoftheIndianonlineretailerwouldyourecommendtoafriend?'])
        plt.xticks(rotation=45)
        plt.figure()

# %% [markdown]
# ##### Amazon and flipkart are most recommended by the customer
